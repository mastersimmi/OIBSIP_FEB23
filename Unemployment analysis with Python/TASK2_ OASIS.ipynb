# %% [markdown]
# # **UNEMPLOYMENT ANALYSIS WITH PYTHON**

# %% [markdown]
# Unemployment is measured by the unemployment rate which is the number of people who are unemployed as a percentage of the total labour force. We have seen a sharp increase in the unemployment rate during Covid-19, so analyzing the unemployment rate can be a good data science project.

# %% [markdown]
# # Step 1: Import the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 2: Load the data into a pandas DataFrame
# *   Unemployment rate upto 2020 dataset

# %%
df = pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
data_set=pd.read_csv('Unemployment in India.csv')

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# # 3. Data pre-processing:

# %% [markdown]
# ### Top and bottom  rows of dataset

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# ...

# %% [markdown]
# ### Total rows and columns in dataset in datasets

# %%
df.shape
# Out:
# (267, 9)

# %% [markdown]
# ### Names of columns in datasets

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ### Datasets information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Check NULL values in datasets

# %%
print("Total NULL values =\n\n",df.isnull().sum())
# Out:
# Total NULL values =
#
#  Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %% [markdown]
# ### Size of datasets

# %%
print("Size of dataset is: ",df.size)
# Out:
# Size of dataset is:  2403

# %% [markdown]
# ### Description of datasets

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# ### Null Value counts in datasets

# %%
df.isnull().value_counts()
# Out:
# Region   Date   Frequency   Estimated Unemployment Rate (%)   Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  longitude  latitude
# False   False  False       False                             False                False                                     False     False      False       267
# dtype: int64

# %% [markdown]
# # 4. Data Visualization    / Exploratory Data Analysis (EDA):

# %% [markdown]
# ## HEAT MAP

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.heatmap(df.corr(), annot=True, cmap="RdPu").set(title='Heatmap of Correlated values for "Unemployment_Rate_upto_11_2020" ')
plt.show()
# Out:
# C:\Users\sohel\AppData\Local\Temp\ipykernel_15888\3825113156.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="RdPu").set(title='Heatmap of Correlated values for "Unemployment_Rate_upto_11_2020" ')

# %% [markdown]
# ## PIE PLOTS

# %%
#PARTITION ACCORDING TO AREA on dataset
fig, ax = plt.subplots(figsize =(5, 4))
#labels
m=['Rural Areas','Urban Areas']
#title for chart
ax.set_title("\nDistribution of Unemployment Across Rural and Urban Areas in India",color="navy")
# Creating color parameters
colors = ( "turquoise", "lavender")
# Creating explode data
explode = (0.2, 0.0)
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "grey" }
# Creating plot
wedges, texts, autotexts = ax.pie(data_set['Area'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = m,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 145,
                                  wedgeprops = wp,
                                  textprops = dict(color ="navy"))
# Adding legend
ax.legend(wedges,m,
          title ="Area Types",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")

plt.show()

# %% [markdown]
# ### PARTITION ACCORDING TO REGION DIRECTIONS IN dataset

# %%
df['Region.1'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %%
fig, ax = plt.subplots(figsize =(5, 4))

# Labels
regions = ['South', 'Northeast', 'East', 'West', 'North']

# Title for chart
ax.set_title("Unemployment by Region in India", color="purple")

# Creating color parameters
colors = ("peachpuff", "turquoise", "burlywood", "gainsboro", "lavender")

# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0)

# Wedge properties
wp = { 'linewidth': 1, 'edgecolor': "darkgreen" }

# Creating plot
wedges, texts, autotexts = ax.pie(df['Region.1'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = regions,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="purple"))

# Adding legend
ax.legend(wedges, regions,
          title = "Region",
          loc = "center left",
          bbox_to_anchor = (1.2, 0, 0.5, 1))

plt.setp(autotexts, size = 8, weight = "bold")

plt.show()

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %% [markdown]
# Unemployment according to Dates in different Regions Directions -
# Estimated Unemployment Rate (%)

# %%
#SCATTER PLOTING
fig = plt.figure(figsize = (9, 6))
sns.scatterplot(x=' Date', y=' Estimated Unemployment Rate (%)',data=df, hue="Region.1")
plt.title('Unemployment Rate by Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %%
#BAR PLOTING
fig = plt.figure(figsize = (9, 6))
sns.barplot(x=' Date', y=' Estimated Unemployment Rate (%)', data=df, hue="Region.1")
plt.title('Unemployment according to Dates in different Regions')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Histogram plots

# %%
fig = plt.figure(figsize = (9, 6))
sns.histplot(df[' Estimated Unemployment Rate (%)'], color='blue', edgecolor='black')
plt.title('Histogram of Estimated Unemployment Rate (%)')
plt.xlabel('Estimated Unemployment Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 5. FINAL DISPLAY OF THE UNEMPLOYMENT RATE IN INDIA  IN 2020 IN INDIA

# %%
fig = plt.figure(figsize = (10, 4))
ax= sns.barplot(y=' Estimated Unemployment Rate (%)', x='Region', data=df ,palette='husl')
ax.set_title("Bar Plot of Unemployment Rates by Region")
ax.set_xlabel("Region")
plt.xticks(rotation=40)
plt.show()
